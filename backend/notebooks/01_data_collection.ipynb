# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import dataset_util

# %%
dataset_util.download_dataset()
# Out:
# ...
# 100%|██████████| 29.3k/29.3k [00:00<00:00, 379kB/s]
# Dataset downloaded to C:\mine\learn\amrita\major-project\repo\backend\data
