# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import dataset_util

# %%
dataset_util.download_dataset()
# Out:
# ...
# 100%|██████████| 29.3k/29.3k [00:00<00:00, 159kB/s]
# Dataset downloaded to C:\mine\learn\amrita\major-project\repo\backend\data\raw
