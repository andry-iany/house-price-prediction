# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import dataset_util

# %%
dataset_util.download_dataset()
# Out:
# ...
# 100%|██████████| 29.3k/29.3k [00:00<00:00, 379kB/s]
# Dataset downloaded to C:\mine\learn\amrita\major-project\repo\backend\data

# %%
from utils.dataset_util import PATH_RAW_DATASET_FILE, PATH_RAW_TRAINING_DATASET, PATH_RAW_TESTING_DATASET
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
housing_dataset = pd.read_csv(PATH_RAW_DATASET_FILE)

# %%
# split datasets into training and testing sets (80/20)

train_df, test_df = train_test_split(housing_dataset, train_size=0.8, random_state=42)

# %%
train_df.to_csv(PATH_RAW_TRAINING_DATASET, index=False)
test_df.to_csv(PATH_RAW_TESTING_DATASET, index=False)
