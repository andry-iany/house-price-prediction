# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from utils.dataset_util import PATH_RAW_TRAINING_DATASET

# %%
housing_dataset = pd.read_csv(PATH_RAW_TRAINING_DATASET)

# %%
housing_dataset.head()
# Out:
#      price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  7525000  6000         3          2        4      yes        no       no
# 1  6300000  7200         3          2        1      yes        no      yes
# 2  3920000  3816         2          1        1      yes        no      yes
# 3  3430000  2610         3          1        2      yes        no      yes
# 4  3010000  3750         3          1        2      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        1       no        furnished
# 1              no             yes        3       no   semi-furnished
# 2              no             yes        2       no        furnished
# 3              no              no        0      yes      unfurnished
# 4              no              no        0       no      unfurnished

# %%
housing_dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  4.360000e+02    436.000000  436.000000  436.000000  436.000000
# mean   4.706527e+06   5154.144495    2.958716    1.266055    1.782110
# std    1.757976e+06   2204.313664    0.747804    0.477391    0.858093
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.498250e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.291000e+06   4500.000000    3.000000    1.000000    2.000000
# 75%    5.600000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.225000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  436.000000
# mean     0.685780
# std      0.854941
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
housing_dataset.shape
# Out:
# (436, 13)

# %%
housing_dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             436 non-null    int64
#  1   area              436 non-null    int64
#  2   bedrooms          436 non-null    int64
#  3   bathrooms         436 non-null    int64
#  4   stories           436 non-null    int64
#  5   mainroad          436 non-null    str
#  6   guestroom         436 non-null    str
#  7   basement          436 non-null    str
#  8   hotwaterheating   436 non-null    str
#  9   airconditioning   436 non-null    str
#  10  parking           436 non-null    int64
#  11  prefarea          436 non-null    str
#  12  furnishingstatus  436 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 44.4 KB

# %%
# Distribution of the target variable (Price)
plt.figure(figsize=(8, 5))
sns.histplot(housing_dataset['price'], color='green', kde=True, bins=30)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
housing_dataset.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'parking'}>]], dtype=object)

# %%
# Correlation Heatmap (only numeric columns)
plt.figure(figsize=(12,8))
numeric_types = housing_dataset.select_dtypes(include=['int64', 'float64'])
sns.heatmap(numeric_types.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()
