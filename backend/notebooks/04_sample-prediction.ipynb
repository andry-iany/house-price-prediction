# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import pickle
from utils.dataset_util import PATH_MODEL, PATH_SAMPLE_TEST, PATH_SCALER, preprocess

# %%
# Load the saved model
with open(PATH_MODEL, 'rb') as file:
    model = pickle.load(file)

# %%
# Load the saved scaler
with open(PATH_SCALER, 'rb') as file:
    scaler = pickle.load(file)

# %%
sample_test = pd.read_csv(PATH_SAMPLE_TEST)

# %%
sample_test = preprocess(sample_test)

# %%
sample_test.head()
# Out:
#      price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  6405000  4800         3          2        4         1          1         0
# 1  6300000  9000         3          1        1         1          0         1
# 2  4900000  4770         3          1        1         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea  \
# 0                0                1        0         0
# 1                0                0        1         1
# 2                0                0        0         0
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                0                             0
# 1                                1                             0
# 2                                1                             0

# %%
X = sample_test.drop('price', axis=1)
y = sample_test['price']

# %%
X = scaler.transform(X)

# %%
prediction = model.predict(X)
prediction
# Out:
# array([6482536.92804011, 5611325.78668517, 3919449.08321767])
